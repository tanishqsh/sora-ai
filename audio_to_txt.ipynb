# %%
import whisper
import os
import time
from tqdm import tqdm  # for progress bar

# 👇 Add the folder containing ffmpeg.exe to the PATH for this session
ffmpeg_path = r"C:\Users\vip\AppData\Local\Microsoft\WinGet\Links"
os.environ["PATH"] += os.pathsep + ffmpeg_path

# Load Whisper model on CPU
model = whisper.load_model("large", device="cpu")

# Arabic prompt to guide transcription
prompt = "هذه مباراة كرة قدم بين فريقي الاتحاد والنصر في الدوري السعودي. يتم ذكر أسماء اللاعبين مثل عبد الرزاق حمدالله، كريستيانو رونالدو، أحمد شراحيلي، وفهد المولد. التعليق يتضمن تمريرات، تسديدات، أهداف، وتسللات. المعلق يصف الحركات بشكل حماسي باللغة العربية."

# Timer
start = time.time()

# Use tqdm to wrap Whisper's internal segments generator
def transcribe_with_progress():
    result = model.transcribe(
        r"C:\My Projects\SCAI\football_match_50_55_audio.mp3",
        language="ar",
        initial_prompt=prompt,
        verbose=True,  # Whisper prints progress info
        fp16=False     # ensure CPU compatibility
    )
    return result

# Run and show elapsed time
result = transcribe_with_progress()
print(f"\n⏱️ Total transcription time: {round(time.time() - start, 2)} seconds\n")

# Output result
print(result["text"])
# Out:
# c:\Users\vip\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\_pytree.py:185: FutureWarning: optree is installed but the version is too old to support PyTorch Dynamo in C++ pytree. C++ pytree support is disabled. Please consider upgrading optree using `python3 -m pip install --upgrade 'optree>=0.13.0'`.
#   warnings.warn(
# c:\Users\vip\AppData\Local\Programs\Python\Python312\Lib\site-packages\whisper\transcribe.py:124: UserWarning: Performing inference on CPU when CUDA is available
#   warnings.warn("Performing inference on CPU when CUDA is available")
# [00:00.000 --> 00:08.420]  تحتضن هذه القمار في أجواب مليئة بالصخب والسحر والمتعم للكروية الكبيرة جدا.
# [00:09.080 --> 00:14.600]  وبالتأكيد في مرعطف مهم جدا، بل أخطر ربما المرعطفات على مستوى الدوري.
# [00:14.600 --> 00:22.260]  من أجري ست نقاط كريم وليست ثلاثة نقاط، ست نقاط كريستيانو وليست مجرد ثلاثة نقاط.
# [00:22.600 --> 00:28.860]  من يسمعني الليلة، من يلبي النداء ويأتي بالانتصار الثمين ويقترب أكثر.
# [00:30.000 --> 00:33.280]  أو يأخذ خطوة مهمة للفومس بنقب الدوري.
# [00:33.360 --> 00:35.760]  طريق لا زال طويل جدا بالتأكيد.
# [00:36.200 --> 00:39.400]  المنافسة ثلاثية للفومس بنقب الدوري.
# [00:39.740 --> 00:43.540]  هذه عادة لكرة كريم اللي كان فيها متسلل.
# [00:43.980 --> 00:47.600]  على يمين الصورة، بنزيمة كان متسلل.
# [00:47.660 --> 00:51.320]  الكرة طويلة مميئة، راسيته بعد وتعود إلى أوتاميو.
# [00:51.780 --> 00:55.900]  يحاول يمر عدى من كارتي، مر هنا، يحافظ على الكورتة.
# [00:56.200 --> 00:59.980]  أوتاميو يغير تجال لعب، لكن توقع سلم جانبي ميتا.
# [01:00.000 --> 01:03.500]  أول كرة على نفسها، بروزوبيتش لمس اليار جيلو.
# [01:03.860 --> 01:06.880]  عدت الكرة لتعود بعد ذلك إلى كارتي.
# [01:07.240 --> 01:12.940]  الليلة مباراة خاصة، لاحظوها، تابعوها بين أوتاميو وكارتي.
# [01:13.300 --> 01:16.340]  كريم في الجهة اليسرى، بنزيمة محاولة خطيرة.
# [01:16.720 --> 01:20.320]  لكن التقضي أمام ميتا في جانبي سيماكان.
# [01:20.640 --> 01:23.860]  اللي ظاهر بقوة أكبر، مباراة بعد أخرى.
# [01:24.140 --> 01:28.100]  وبالتأكيد أصبح رقما مهما، خيارا أساسيا.
# [01:28.100 --> 01:29.100]  موسيقى
# [01:30.000 --> 01:32.620]  لسغناء عنا حلوى التبليلات التحديا خطيرة.
# [01:32.980 --> 01:34.600]  بيرخفاين تسجيلة.
# [01:35.000 --> 01:37.000]  يا إلهي.
# [01:38.780 --> 01:40.760]  الله الله الله على الكرة.
# [01:41.360 --> 01:43.280]  أبا بابا بابا على الكرة.
# [01:43.660 --> 01:45.500]  قوي أمير بيرخفاين.
# [01:45.940 --> 01:47.620]  وتالوكي بنتو.
# [01:47.840 --> 01:50.060]  بنتو بثبات بنتو.
# [01:50.440 --> 01:53.400]  ينجح في التصدي في هذا التحدي.
# [01:53.400 --> 01:58.100]  مع أولم الكرات اللي على المرمى بين الخشبات الثلاث.
# [01:58.460 --> 01:59.900]  لسيبن في هذه المباراة.
# [02:00.000 --> 02:02.760]  العودة بعد ذلك لأمريكا لبورت.
# [02:02.760 --> 02:06.760]  بدأ أن الهدف قادم واقترب في أي نحو.
# [02:06.760 --> 02:09.760]  سيأتي في أي شباك.
# [02:09.760 --> 02:13.760]  وأي شباك ستهتز أمير المدرة الليلة.
# [02:13.760 --> 02:16.760]  اللي سيحتفل بثلاثة نقاط خمينا يا أنتيلو.
# [02:16.760 --> 02:18.000]  أنتيلو أنتيلو.
# [02:18.000 --> 02:20.000]  أنتيلو يحاول عد ياتي ريونا.
# [02:20.000 --> 02:21.340]  تصل لمصاعتي.
# [02:21.340 --> 02:24.000]  رونالدو يحاول يمر من الأول.
# [02:24.000 --> 02:25.500]  يحافظ على الكرة.
# [02:25.500 --> 02:27.000]  يكسب الخطأ عملا.
# [02:27.000 --> 02:28.000]  ناسارت في اللعب.
# [02:28.000 --> 02:29.000]  عادت بعد ذلك.
# [02:29.000 --> 02:29.840]  لمصاعتي.
# [02:29.840 --> 02:30.840]  لمصاعتي الانتحاد.
# [02:30.840 --> 02:31.840]  هي مرتدة لي.
# [02:31.840 --> 02:34.840]  عوار. عوار. عاد عوار.
# [02:34.840 --> 02:35.840]  غيرت جلب.
# [02:35.840 --> 02:37.840]  جميلة باتجاه كريم.
# [02:37.840 --> 02:38.840]  تحرك العبود.
# [02:38.840 --> 02:41.840]  خطيرة انتحادية محاولة مرور.
# [02:41.840 --> 02:44.840]  ونزلت هي لكريم تسجيده.
# [02:54.840 --> 02:55.840]  أي لقطة.
# [02:55.840 --> 02:58.840]  أي تسجيدة جميلة جميلة.
# [02:58.840 --> 03:00.840]  تصدق عادي.
# [03:00.840 --> 03:02.840]  كرة بنزيمة.
# [03:02.840 --> 03:03.840]  باتجاه المرمى.
# [03:03.840 --> 03:05.840]  بنت رفضها.
# [03:05.840 --> 03:08.840]  تحركت من أجل هالجماهير.
# [03:08.840 --> 03:10.840]  سمعنا بقوة للآهات.
# [03:10.840 --> 03:14.840]  وبالتأكيد لهذا الحماس الكبير في المدرجات.
# [03:14.840 --> 03:16.840]  نشوفها مرة أخرى.
# [03:16.840 --> 03:17.840]  الكرة لبريقاين.
# [03:17.840 --> 03:18.840]  عرضية.
# [03:18.840 --> 03:19.840]  دفاع تدخل.
# [03:19.840 --> 03:24.840]  الاتحاد الآن يزيد من حد بالضغط في مناطق النصر.
# [03:24.840 --> 03:27.840]  البحث مستمر عن هدف أول في هذه القمة.
# [03:28.840 --> 03:29.840]  كانتي.
# [03:29.840 --> 03:31.840]  وحاولت مرور.
# [03:31.840 --> 03:32.840]  بتاني بيموهند.
# [03:32.840 --> 03:35.840]  شنق تحت كرة في تيانتي اليوسرا.
# [03:35.840 --> 03:38.840]  بيتاي يلعب كرة عرضية خطيرة.
# [03:38.840 --> 03:40.840]  الدفاع تدخل لكن بالخطأ.
# [03:40.840 --> 03:42.840]  الآن عند عوار.
# [03:42.840 --> 03:44.840]  عوار يلعبون في تيانتي اليوم نعم.
# [03:44.840 --> 03:46.840]  عبد الرحمن.
# [03:46.840 --> 03:47.840]  العبود.
# [03:47.840 --> 03:49.840]  العبود يحاول.
# [03:49.840 --> 03:52.840]  العبود يلعب كرة.
# [03:52.840 --> 03:54.840]  الونتو جميلة مع عوار.
# [03:54.840 --> 03:56.840]  ومع ذلك برون جميل.
# [03:56.840 --> 03:57.840]  الكرة عدت.
# [03:57.840 --> 03:59.840]  وحاولت بعد ذلك إلى وجود خطأ.
# [03:59.840 --> 04:01.840]  لمصاعة عبد الرحمن العبود.
# [04:01.840 --> 04:02.840]  بالسلامة ان شاء الله.
# [04:02.840 --> 04:03.840]  الغنام.
# [04:03.840 --> 04:05.840]  اتكلم مع حاكم المباراة.
# [04:05.840 --> 04:07.840]  انه لا عم يدعى الصقور.
# [04:07.840 --> 04:08.840]  الحاكم.
# [04:08.840 --> 04:10.840]  اشار انه لا.
# [04:10.840 --> 04:12.840]  انه فيه تدخل يا غنام.
# [04:12.840 --> 04:14.840]  وبالتالي فيه خطأ.
# [04:14.840 --> 04:15.840]  في هذه الاثناء.
# [04:15.840 --> 04:16.840]  على السلطان.
# [04:16.840 --> 04:18.840]  ولمصاعة عبد الرحمن العبود.
# [04:18.840 --> 04:20.840]  ثبانية وعشرين دقيقة لعب.
# [04:20.840 --> 04:22.840]  تسعة وعشرين دقيقة.
# [04:22.840 --> 04:25.840]  هل هو وقت الهدف الأول في القمة.
# [04:25.840 --> 04:26.840]  نتساءل.
# [04:26.840 --> 04:27.840]  واياكم.
# [04:27.840 --> 04:29.840]  ننتظر واياكم.
# [04:29.840 --> 04:31.840]  الكرة لمصاعة عوار.
# [04:31.840 --> 04:33.840]  على تنفيذ خطأ.
# [04:33.840 --> 04:34.840]  في منتال خطورة.
# [04:34.840 --> 04:35.840]  بريرا.
# [04:35.840 --> 04:36.840]  فامينهو.
# [04:36.840 --> 04:37.840]  بنزيمة.
# [04:37.840 --> 04:38.840]  كادش.
# [04:38.840 --> 04:39.840]  والبقية انتظار.
# [04:39.840 --> 04:41.840]  للنصر متراجع الآن.
# [04:41.840 --> 04:44.840]  للحفاظ على وضعيته في هذه القمة.
# [04:44.840 --> 04:48.840]  مع فرصة انتحادية تبدو في منتال خطورة.
# [04:48.840 --> 04:49.840]  الكرة من تاني بعوار.
# [04:49.840 --> 04:50.840]  أرضية خطيرة.
# [04:50.840 --> 04:53.840]  لكن الدفاع خلصها ايبريك.
# [04:53.840 --> 04:55.840]  لابوت.
# [04:55.840 --> 04:56.840]  بيروفوك.
# [04:56.840 --> 04:57.840]  تباين.
# [04:57.840 --> 04:58.840]  تعود الكرة من جانبي.
# [04:58.840 --> 04:59.840]  كانتي.
# [04:59.840 --> 05:00.840]  طويلة أمامية.
# [05:00.840 --> 05:01.840]  الله للاستقبال.
# [05:01.840 --> 05:03.840]  على الكنترول الجميل.
# [05:03.840 --> 05:05.840]  يا إلهي عوار.
# [05:05.840 --> 05:06.840]  وسامة يحاول مر.
# [05:06.840 --> 05:08.840]  تدخل أمام أكثر من اللاعب.
# [05:08.840 --> 05:09.840]  لا زالت ابتحادية.
# [05:09.840 --> 05:11.840]  لابوت يم الكرة النصر.
# [05:11.840 --> 05:14.840]  ثم بعد ذلك تدخل أمام أفريسيارو.
# [05:14.840 --> 05:18.840]  وفلقي الكرة تحولت إلى رمية جانبية.
# [05:18.840 --> 05:19.840]  برافو.
# [05:19.840 --> 05:20.840]  برافو عبد الرحمن.
# [05:20.840 --> 05:21.840]  برافو.
# [05:21.840 --> 05:22.840]  الاعتذار.
# [05:22.840 --> 05:25.840]  بعد إبعاد الكرة في اللقطة الماضية أمام رونادو.
# [05:25.840 --> 05:27.840]  أنه أنا كنت أحاول إبعاد الكرة.
# [05:27.840 --> 05:29.840]  لا أكثر ولا أقل كريستيانو.
# [05:29.840 --> 05:31.840]  اعتواجة ماهرية كبيرة جدا.
# [05:31.840 --> 05:33.840]  في مدرج الاتحاد.
# [05:33.840 --> 05:36.840]  هنا وانتظار لدقائق قادمة صعبة.
# [05:36.840 --> 05:37.840]  في هذه الكمبة.
# [05:37.840 --> 05:39.840]  كرة تعود مرة أخرى.
# [05:39.840 --> 05:42.840]  خرجت من ساديو ماري إلى رمية جانبية.
# [05:42.840 --> 05:43.840]  إلى الدقائق.
# [05:43.840 --> 05:45.840]  يشعر فيها ربما.
# [05:45.840 --> 05:46.840]  سيمانو بيولي.
# [05:46.840 --> 05:48.840]  بخطورة الموقف.
# [05:48.840 --> 05:51.840]  أنه الاتحاديين كانوا قريبين في أكثر من لقطة.
# [05:51.840 --> 05:53.840]  بنتو تصدى في مرة.
# [05:53.840 --> 05:55.840]  الدفاع تصدى في أخرى.
# [05:55.840 --> 05:58.840]  كان الاتحاد في منتهى الخطورة في الدقائق الماضية.
# [05:58.840 --> 06:00.840]  الآن كرة في وسط الميدان.
# [06:00.840 --> 06:03.840]  لذلك بيولي يحب أن اللاعبين.
# [06:03.840 --> 06:06.840]  يتماسكون أكثر.
# [06:06.840 --> 06:10.840]  ويلعبون بثقة أكبر في دقائق القادمة.
# [06:10.840 --> 06:15.840]  من أجل الحصول على نتيجة إيجابية في مباراة الليلة.
# [06:15.840 --> 06:17.840]  كرة تعود إلى سيباكان.
# [06:17.840 --> 06:19.840]  سيباكان.
# [06:19.840 --> 06:20.840]  سيباكان.
# [06:20.840 --> 06:21.840]  سيباكان.
# [06:21.840 --> 06:28.840]  يغير اللاعب في جيئة اليمنى.
# [06:28.840 --> 06:29.840]  الغنام.
# [06:29.840 --> 06:32.840]  عودة للوراء.
# [06:32.840 --> 06:37.840]  بتموعة من التمريرات.
# [06:37.840 --> 06:38.840]  بحثا عن مساحة.
# [06:38.840 --> 06:40.840]  عن حل الكرة الطويلة.
# [06:40.840 --> 06:41.840]  سيباكان.
# [06:41.840 --> 06:42.840]  لكن التقديم الجانبي.
# [06:42.840 --> 06:43.840]  داريلو بيريرا.
# [06:43.840 --> 06:46.840]  بيريرا تقريبا كان على لعبين من المصر.
# [06:46.840 --> 06:48.840]  رغم ذلك كانت تصرف رائع.
# [06:48.840 --> 06:49.840]  الآن.
# [06:49.840 --> 06:50.840]  الجمهور.
# [06:50.840 --> 06:53.040]  العالمي في هذه اللقطة
# [06:53.040 --> 06:54.700]  والمساندة الكبيرة
# [06:54.700 --> 06:56.460]  والإيمان الكامل
# [06:56.460 --> 06:58.240]  بقدرة النصر على
# [06:58.240 --> 07:00.940]  المنافسة بقوة والفوز
# [07:00.940 --> 07:01.940]  بلقب الدوري
# [07:01.940 --> 07:05.160]  لا زال في أذهان عشاقة
# [07:05.160 --> 07:07.400]  كرة طويلة مرت من الجميع
# [07:07.400 --> 07:09.020]  هي خطيرة لساد يوبرين
# [07:09.020 --> 07:10.940]  واحد على واحد أمام مهند
# [07:10.940 --> 07:12.980]  محاولة خطيرة نصروية
# [07:12.980 --> 07:15.160]  ماري عرضية لمن
# [07:15.160 --> 07:17.420]  فرصة لكنها مرت على ما يبدو
# [07:17.420 --> 07:19.420]  خارجتنا ضربة مرمى
# [07:19.420 --> 07:21.360]  في إشارة الحكم المساعد
# [07:21.360 --> 07:22.980]  على الكرة وهي في الهواء
# [07:22.980 --> 07:25.360]  بدون تاليسكا في هذه المباراة
# [07:25.360 --> 07:26.840]  بالنسبة لبيونلي
# [07:26.840 --> 07:29.480]  والاعتماد على
# [07:29.480 --> 07:30.980]  آنجيلو
# [07:30.980 --> 07:33.640]  جناح يمين وساد يوبرين
# [07:33.640 --> 07:34.920]  جناح يسار
# [07:34.920 --> 07:39.460]  يأخذ حرية أكبر
# [07:39.460 --> 07:40.900]  بالتأكيد أوتافيو
# [07:40.900 --> 07:43.820]  المباراة الحقيقية في المدرجات
# [07:43.820 --> 07:45.360]  رغم وجود
# [07:45.360 --> 07:47.740]  أساطير على المستطيل الأخضر
# [07:47.740 --> 07:49.320]  لكن تبهرنا
# [07:49.320 --> 07:51.400]  أكثر الأجوال الجماهيرية
# [07:51.400 --> 07:52.560]  في الجوهر المشعة
# [07:52.560 --> 07:54.540]  كرة تعود مرة أخرى لبنتو
# [07:54.540 --> 08:07.740]  بنتو إلى بوشل
# [08:07.740 --> 08:10.860]  رأسي تصل بعد ذلك إلى
# [08:10.860 --> 08:11.880]  ساديو موني
# [08:11.880 --> 08:13.120]  يحافظ على كورتا
# [08:13.120 --> 08:14.860]  على اليسار خطيرة لبوشل
# [08:14.860 --> 08:17.000]  انطلاق نصروية في مكان خطير
# [08:17.000 --> 08:18.780]  بوشل يحاول في هذه الأثناء
# [08:19.320 --> 08:21.560]  أن يكون مرور كرة خطيرة
# [08:21.560 --> 08:23.120]  ولكن لا أحد هنا
# [08:23.120 --> 08:24.200]  يأتي إلى أي لقطة
# [08:24.200 --> 08:25.920]  جميلة من بوشل
# [08:25.920 --> 08:28.780]  تأخر في التسليم
# [08:28.780 --> 08:30.040]  ضاعت اللقطة
# [08:30.040 --> 08:32.140]  عادت التحدي في هذه الأثناء
# [08:32.140 --> 08:34.320]  الحكم يشير إلى أوتوده
# [08:34.320 --> 08:36.180]  خطأ لبيركفايل
# [08:36.180 --> 08:38.740]  حتمه بمجهود فردي
# [08:38.740 --> 08:40.940]  نواف كان في شك متسلل
# [08:40.940 --> 08:41.720]  لكن
# [08:41.720 --> 08:45.220]  لم يكن في تسلل في قرار الحكم
# [08:45.220 --> 08:46.780]  سمرت اللعبة
# [08:46.780 --> 08:48.560]  عدى من الأول من الثاني
# [08:49.320 --> 08:50.680]  رونادو كان بعيد
# [08:50.680 --> 08:52.640]  وتاميو كان بعيد
# [08:52.640 --> 08:55.800]  أنجيلو حاول في لقطة تأخر في التسليم
# [08:55.800 --> 08:57.680]  وبالتالي ضاعت الهجمة
# [08:57.680 --> 08:59.640]  على النصر
# [08:59.640 --> 09:00.760]  لتعود مرة أخرى
# [09:00.760 --> 09:02.680]  شنقيطيو حاول في هذه الأثناء
# [09:02.680 --> 09:04.560]  تدخل ورمية جانبية
# [09:04.560 --> 09:06.020]  رمية جانبية
# [09:06.020 --> 09:09.540]  واجه ضغوطات كبيرة في بداية الموسم
# [09:09.540 --> 09:10.300]  لوران بلام
# [09:10.300 --> 09:14.540]  وفضل الرد في النتائج
# [09:14.540 --> 09:17.040]  لذلك يحظى بالثقة الكاملة
# [09:17.040 --> 09:19.040]  بعد العمل الكبير جدا مع فريقه
# [09:19.320 --> 09:20.680]  والفوز
# [09:20.680 --> 09:25.240]  في تبيع مباراة هذا الموسم
# [09:25.240 --> 09:26.520]  في مختلف المسابقات
# [09:26.520 --> 09:28.320]  باستثناء مباراة وحيدة في الدوري
# [09:28.320 --> 09:30.820]  الفريق بعد ذلك
# [09:30.820 --> 09:33.540]  يحقق أرقام رائعة جدا
# [09:33.540 --> 09:34.780]  مع المدرب لوران بلام
# [09:34.780 --> 09:37.880]  بالنسبة للاتحاد
# [09:37.880 --> 09:38.800]  في هذا الموسم
# [09:38.800 --> 09:39.960]  كرة في أتاق طيب
# [09:39.960 --> 09:41.720]  لتعود مرة أخرى
# [09:41.720 --> 09:45.700]  تمريره بالتجاه
# [09:45.700 --> 09:46.780]  عوار
# [09:46.780 --> 09:49.100]  بيرغ فاين في الجهة اليسرى
# [09:49.320 --> 09:51.080]  يحافظ على كرة
# [09:51.080 --> 09:52.780]  ينتظر مساندة أكبر
# [09:52.780 --> 09:54.440]  يلعب الكرة العرضية خطيرة
# [09:54.440 --> 09:55.320]  لكنها في يد بنته
# [09:55.320 --> 09:56.520]  حلو للأفضل
# [09:56.520 --> 09:58.920]  جميلة من جانبي بيرغ فاين
# [09:58.920 --> 10:00.920]  هي مباراة كبيرة أيضا لبنته
# [10:00.920 --> 10:03.600]  بنته رائع في تدخلاتها في هذه المباراة
# [10:03.600 --> 10:05.600]  تمرير لكريسيانو
# [10:05.600 --> 10:07.600]  متسلل رونالدو
# [10:07.600 --> 10:09.600]  متسلل رونالدو في هذه اللبنة
# [10:14.520 --> 10:17.480]  تسلل على رونالدو
# [10:19.320 --> 10:21.840]  مباشرة كبيرة
# [10:21.840 --> 10:22.420]  مباشرة كبيرة
# [10:22.420 --> 10:23.940]  مباشرة كبيرة
# [10:23.940 --> 10:25.040]  لدائما ما يغنون
# [10:25.040 --> 10:27.920]  أصفر و أسود مقلم
# [10:27.920 --> 10:29.800]  سكن فؤاد
# [10:29.800 --> 10:31.900]  جماهير اتحادية بأجواهها
# [10:31.900 --> 10:33.200]  بأجواهها الرائعة
# [10:33.200 --> 10:35.200]  حضور جماهير مصراوي أيضا
# [10:35.200 --> 10:37.260]  في المكان
#
# ⏱️ Total transcription time: 644.07 seconds
#
#  تحتضن هذه القمار في أجواب مليئة بالصخب والسحر والمتعم للكروية الكبيرة جدا. وبالتأكيد في مرعطف مهم جدا، بل أخطر ربما المرعطفات على مستوى الدوري. من أجري ست نقاط كريم وليست ثلاثة نقاط، ست نقاط كريستيانو وليست مجرد ثلاثة نقاط. من يسمعني الليلة، من يلبي النداء ويأتي بالانتصار الثمين ويقترب أكثر. أو يأخذ خطوة مهمة للفومس بنقب الدوري. طريق لا زال طويل جدا بالتأكيد. المنافسة ثلاثية للفومس بنقب الدوري. هذه عادة لكرة كريم اللي كان فيها متسلل. على يمين الصورة، بنزيمة كان متسلل. الكرة طويلة مميئة، راسيته بعد وتعود إلى أوتاميو. يحاول يمر عدى من كارتي، مر هنا، يحافظ على الكورتة. أوتاميو يغير تجال لعب، لكن توقع سلم جانبي ميتا. أول كرة على نفسها، بروزوبيتش لمس اليار جيلو. عدت الكرة لتعود بعد ذلك إلى كارتي. الليلة مباراة خاصة، لاحظوها، تابعوها بين أوتاميو وكارتي. كريم في الجهة اليسرى، بنزيمة محاولة خطيرة. لكن التقضي أمام ميتا في جانبي سيماكان. اللي ظاهر بقوة أكبر، مباراة بعد أخرى. وبالتأكيد أصبح رقما مهما، خيارا أساسيا. موسيقى لسغناء عنا حلوى التبليلات التحديا خطيرة. بيرخفاين تسجيلة. يا إلهي. الله الله الله على الكرة. أبا بابا بابا على الكرة. قوي أمير بيرخفاين. وتالوكي بنتو. بنتو بثبات بنتو. ينجح في التصدي في هذا التحدي. مع أولم الكرات اللي على المرمى بين الخشبات الثلاث. لسيبن في هذه المباراة. العودة بعد ذلك لأمريكا لبورت. بدأ أن الهدف قادم واقترب في أي نحو. سيأتي في أي شباك. وأي شباك ستهتز أمير المدرة الليلة. اللي سيحتفل بثلاثة نقاط خمينا يا أنتيلو. أنتيلو أنتيلو. أنتيلو يحاول عد ياتي ريونا. تصل لمصاعتي. رونالدو يحاول يمر من الأول. يحافظ على الكرة. يكسب الخطأ عملا. ناسارت في اللعب. عادت بعد ذلك. لمصاعتي. لمصاعتي الانتحاد. هي مرتدة لي. عوار. عوار. عاد عوار. غيرت جلب. جميلة باتجاه كريم. تحرك العبود. خطيرة انتحادية محاولة مرور. ونزلت هي لكريم تسجيده. أي لقطة. أي تسجيدة جميلة جميلة. تصدق عادي. كرة بنزيمة. باتجاه المرمى. بنت رفضها. تحركت من أجل هالجماهير. سمعنا بقوة للآهات. وبالتأكيد لهذا الحماس الكبير في المدرجات. نشوفها مرة أخرى. الكرة لبريقاين. عرضية. دفاع تدخل. الاتحاد الآن يزيد من حد بالضغط في مناطق النصر. البحث مستمر عن هدف أول في هذه القمة. كانتي. وحاولت مرور. بتاني بيموهند. شنق تحت كرة في تيانتي اليوسرا. بيتاي يلعب كرة عرضية خطيرة. الدفاع تدخل لكن بالخطأ. الآن عند عوار. عوار يلعبون في تيانتي اليوم نعم. عبد الرحمن. العبود. العبود يحاول. العبود يلعب كرة. الونتو جميلة مع عوار. ومع ذلك برون جميل. الكرة عدت. وحاولت بعد ذلك إلى وجود خطأ. لمصاعة عبد الرحمن العبود. بالسلامة ان شاء الله. الغنام. اتكلم مع حاكم المباراة. انه لا عم يدعى الصقور. الحاكم. اشار انه لا. انه فيه تدخل يا غنام. وبالتالي فيه خطأ. في هذه الاثناء. على السلطان. ولمصاعة عبد الرحمن العبود. ثبانية وعشرين دقيقة لعب. تسعة وعشرين دقيقة. هل هو وقت الهدف الأول في القمة. نتساءل. واياكم. ننتظر واياكم. الكرة لمصاعة عوار. على تنفيذ خطأ. في منتال خطورة. بريرا. فامينهو. بنزيمة. كادش. والبقية انتظار. للنصر متراجع الآن. للحفاظ على وضعيته في هذه القمة. مع فرصة انتحادية تبدو في منتال خطورة. الكرة من تاني بعوار. أرضية خطيرة. لكن الدفاع خلصها ايبريك. لابوت. بيروفوك. تباين. تعود الكرة من جانبي. كانتي. طويلة أمامية. الله للاستقبال. على الكنترول الجميل. يا إلهي عوار. وسامة يحاول مر. تدخل أمام أكثر من اللاعب. لا زالت ابتحادية. لابوت يم الكرة النصر. ثم بعد ذلك تدخل أمام أفريسيارو. وفلقي الكرة تحولت إلى رمية جانبية. برافو. برافو عبد الرحمن. برافو. الاعتذار. بعد إبعاد الكرة في اللقطة الماضية أمام رونادو. أنه أنا كنت أحاول إبعاد الكرة. لا أكثر ولا أقل كريستيانو. اعتواجة ماهرية كبيرة جدا. في مدرج الاتحاد. هنا وانتظار لدقائق قادمة صعبة. في هذه الكمبة. كرة تعود مرة أخرى. خرجت من ساديو ماري إلى رمية جانبية. إلى الدقائق. يشعر فيها ربما. سيمانو بيولي. بخطورة الموقف. أنه الاتحاديين كانوا قريبين في أكثر من لقطة. بنتو تصدى في مرة. الدفاع تصدى في أخرى. كان الاتحاد في منتهى الخطورة في الدقائق الماضية. الآن كرة في وسط الميدان. لذلك بيولي يحب أن اللاعبين. يتماسكون أكثر. ويلعبون بثقة أكبر في دقائق القادمة. من أجل الحصول على نتيجة إيجابية في مباراة الليلة. كرة تعود إلى سيباكان. سيباكان. سيباكان. سيباكان. يغير اللاعب في جيئة اليمنى. الغنام. عودة للوراء. بتموعة من التمريرات. بحثا عن مساحة. عن حل الكرة الطويلة. سيباكان. لكن التقديم الجانبي. داريلو بيريرا. بيريرا تقريبا كان على لعبين من المصر. رغم ذلك كانت تصرف رائع. الآن.  ...

# %%
with open("arabic_commentator_transcript.txt", "w", encoding="utf-8") as f:
    f.write(result['text'])

# %%
# Save to TXT
output_path = r"C:\My Projects\SCAI\football_match_50_55_transcript.txt"
with open(output_path, "w", encoding="utf-8") as f:
    f.write(result["text"])

print(f"\n📝 Transcription saved to: {output_path}")
